# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
car=pd.read_csv('/content/dataset.csv')

# %%
car
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0                 72000       CNG       Manual      First  26.6 km/kg
# 1                 41000    Diesel       Manual      First  19.67 kmpl
# 2                 46000    Petrol       Manual      First   18.2 kmpl
# 3                 87000    Diesel       Manual      First  20.77 kmpl
# 4                 40670    Diesel    Automatic     Second   15.2 kmpl
# ...                 ...       ...          ...        ...         ...
# 6014              27365    Diesel       Manual      First   28.4 kmpl
# 6015             100000    Diesel       Manual      First   24.4 kmpl
# 6016              55000    Diesel       Manual     Second   14.0 kmpl
# 6017              46000    Petrol       Manual      First   18.9 kmpl
# 6018              47000    Diesel       Manual      First  25.44 kmpl
#
#        Engine      Power  Seats  New_Price  Price
# 0      998 CC  58.16 bhp    5.0        NaN   1.75
# 1     1582 CC  126.2 bhp    5.0        NaN  12.50
# 2     1199 CC   88.7 bhp    5.0  8.61 Lakh   4.50
# 3     1248 CC  88.76 bhp    7.0        NaN   6.00
# 4     1968 CC  140.8 bhp    5.0        NaN  17.74
# ...       ...        ...    ...        ...    ...
# 6014  1248 CC     74 bhp    5.0  7.88 Lakh   4.75
# 6015  1120 CC     71 bhp    5.0        NaN   4.00
# 6016  2498 CC    112 bhp    8.0        NaN   2.90
# 6017   998 CC   67.1 bhp    5.0        NaN   2.65
# 6018   936 CC   57.6 bhp    5.0        NaN   2.50
#
# [6019 rows x 14 columns]

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         6019 non-null   int64
#  1   Name               6019 non-null   object
#  2   Location           6019 non-null   object
#  3   Year               6019 non-null   int64
#  4   Kilometers_Driven  6019 non-null   int64
#  5   Fuel_Type          6019 non-null   object
#  6   Transmission       6019 non-null   object
#  7   Owner_Type         6019 non-null   object
#  8   Mileage            6017 non-null   object
#  9   Engine             5983 non-null   object
#  10  Power              5983 non-null   object
#  11  Seats              5977 non-null   float64
#  12  New_Price          824 non-null    object
#  13  Price              6019 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 658.5+ KB

# %%
car.isnull().sum()
# Out:
# Unnamed: 0              0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  42
# New_Price            5195
# Price                   0
# dtype: int64

# %%
# prompt: plot heat map for missing value in each varible

plt.figure(figsize=(10, 6))
sns.heatmap(car.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
# prompt: drop the missing value

car.dropna(inplace=True)
car.isnull().sum()
# Out:
# Unnamed: 0           0
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# New_Price            0
# Price                0
# dtype: int64

# %%
# most of the values are missing for New_Price, drop New_Price Column

car.drop(['New_Price'],axis=1,inplace=True)

# %%
# drop raw with missing values

car.dropna(inplace=True)
car.isnull().sum()
car.info()
car.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 823 entries, 2 to 6014
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         823 non-null    int64
#  1   Name               823 non-null    object
#  2   Location           823 non-null    object
#  3   Year               823 non-null    int64
#  4   Kilometers_Driven  823 non-null    int64
#  5   Fuel_Type          823 non-null    object
#  6   Transmission       823 non-null    object
#  7   Owner_Type         823 non-null    object
#  8   Mileage            823 non-null    object
#  9   Engine             823 non-null    object
#  10  Power              823 non-null    object
#  11  Seats              823 non-null    float64
#  12  Price              823 non-null    float64
# dtypes: float64(2), int64(3), object(8)
# memory usage: 90.0+ KB
# (823, 13)

# %%
car.describe()
# Out:
#         Unnamed: 0         Year  Kilometers_Driven       Seats       Price
# count   823.000000   823.000000         823.000000  823.000000  823.000000
# mean   3017.058323  2015.869988       40498.402187    5.304982   13.647606
# std    1775.572600     2.378709       28791.171759    0.795707   14.860539
# min       2.000000  2001.000000         600.000000    2.000000    0.700000
# 25%    1522.000000  2015.000000       20487.500000    5.000000    5.000000
# 50%    2916.000000  2016.000000       34895.000000    5.000000    8.200000
# 75%    4650.500000  2017.000000       53829.000000    5.000000   17.500000
# max    6014.000000  2019.000000      215000.000000    8.000000  160.000000

# %%
sns.pairplot(car)

# %%
# prompt: Unique values in Name and count

# Count unique values in the 'Name' column
name_counts = car['Name'].value_counts()
name_counts
# Out:
# Name
# Maruti Alto K10 VXI                        16
# Toyota Innova Crysta 2.8 ZX AT             14
# BMW 3 Series 320d                          13
# BMW 5 Series 520d Luxury Line              12
# Maruti Vitara Brezza ZDi Plus Dual Tone    12
#                                            ..
# BMW 3 Series Sport                          1
# Honda WR-V Edge Edition i-VTEC S            1
# Mercedes-Benz GLA Class 200 d Style         1
# Maruti Wagon R VXI AMT1.2                   1
# Tata Bolt Revotron XT                       1
# Name: count, Length: 321, dtype: int64

# %%
# prompt: split Name variable

# Split the 'Name' column into multiple columns
car[['Manufacturer', 'Model']] = car['Name'].str.split(' ',n=1, expand=True)

# Display the updated DataFrame
car
# Out:
#       Unnamed: 0                               Name Location  Year  \
# 2              2                       Honda Jazz V  Chennai  2011
# 7              7  Toyota Innova Crysta 2.8 GX AT 8S   Mumbai  2016
# 10            10                   Maruti Ciaz Zeta    Kochi  2018
# 15            15        Mitsubishi Pajero Sport 4X4    Delhi  2014
# 20            20                  BMW 3 Series 320d    Kochi  2014
# ...          ...                                ...      ...   ...
# 5999        5999              Tata Bolt Revotron XT  Chennai  2016
# 6002        6002      Volkswagen Vento 1.6 Highline   Mumbai  2011
# 6005        6005           Maruti Vitara Brezza VDi     Pune  2016
# 6010        6010               Honda Brio 1.2 VX MT    Delhi  2013
# 6014        6014                   Maruti Swift VDI    Delhi  2014
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 2                 46000    Petrol       Manual      First   18.2 kmpl
# 7                 36000    Diesel    Automatic      First  11.36 kmpl
# 10                25692    Petrol       Manual      First  21.56 kmpl
# 15               110000    Diesel       Manual      First   13.5 kmpl
# 20                32982    Diesel    Automatic      First  22.69 kmpl
# ...                 ...       ...          ...        ...         ...
# 5999              10000    Petrol       Manual      First  17.57 kmpl
# 6002              38000    Petrol       Manual      First  16.09 kmpl
# 6005              37208    Diesel       Manual      First   24.3 kmpl
# 6010              33746    Petrol       Manual      First   18.5 kmpl
# 6014              27365    Diesel       Manual      First   28.4 kmpl
#
#        Engine       Power  Seats  Price Manufacturer  \
# 2     1199 CC    88.7 bhp    5.0   4.50        Honda
# 7     2755 CC   171.5 bhp    8.0  17.50       Toyota
# 10    1462 CC  103.25 bhp    5.0   9.95       Maruti
# 15    2477 CC  175.56 bhp    7.0  15.00   Mitsubishi
# 20    1995 CC     190 bhp    5.0  18.55          BMW
# ...       ...         ...    ...    ...          ...
# 5999  1193 CC    88.7 bhp    5.0   4.00         Tata
# 6002  1598 CC   103.5 bhp    5.0   3.25   Volkswagen
# 6005  1248 CC    88.5 bhp    5.0   7.43       Maruti
# 6010  1198 CC    86.8 bhp    5.0   3.20        Honda
# 6014  1248 CC      74 bhp    5.0   4.75       Maruti
#
#                            Model
# 2                         Jazz V
# 7     Innova Crysta 2.8 GX AT 8S
# 10                     Ciaz Zeta
# 15              Pajero Sport 4X4
# 20                 3 Series 320d
# ...                          ...
# 5999            Bolt Revotron XT
# 6002          Vento 1.6 Highline
# 6005           Vitara Brezza VDi
# 6010              Brio 1.2 VX MT
# 6014                   Swift VDI
#
# [823 rows x 15 columns]

# %%
car.drop(['Name'],axis=1,inplace=True)

# %%
# prompt: remove string valur in Mileage ,Power, Engine

# Remove string values in 'Mileage', 'Power', and 'Engine' columns

# Define a function to clean the columns
def clean_column(value):
    if isinstance(value, str):  # Check if the value is a string
        value = value.split(" ")[0]  # Split at space, take the first part
        try:
          return float(value) #Convert to float
        except ValueError:
          return np.nan # Handle cases where conversion fails
    return value


car['Mileage'] = car['Mileage'].apply(clean_column)
car['Power'] = car['Power'].apply(clean_column)
car['Engine'] = car['Engine'].apply(clean_column)

# %%
car
# Out:
#       Unnamed: 0 Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 2              2  Chennai  2011              46000    Petrol       Manual
# 7              7   Mumbai  2016              36000    Diesel    Automatic
# 10            10    Kochi  2018              25692    Petrol       Manual
# 15            15    Delhi  2014             110000    Diesel       Manual
# 20            20    Kochi  2014              32982    Diesel    Automatic
# ...          ...      ...   ...                ...       ...          ...
# 5999        5999  Chennai  2016              10000    Petrol       Manual
# 6002        6002   Mumbai  2011              38000    Petrol       Manual
# 6005        6005     Pune  2016              37208    Diesel       Manual
# 6010        6010    Delhi  2013              33746    Petrol       Manual
# 6014        6014    Delhi  2014              27365    Diesel       Manual
#
#      Owner_Type  Mileage  Engine   Power  Seats  Price Manufacturer  \
# 2         First    18.20  1199.0   88.70    5.0   4.50        Honda
# 7         First    11.36  2755.0  171.50    8.0  17.50       Toyota
# 10        First    21.56  1462.0  103.25    5.0   9.95       Maruti
# 15        First    13.50  2477.0  175.56    7.0  15.00   Mitsubishi
# 20        First    22.69  1995.0  190.00    5.0  18.55          BMW
# ...         ...      ...     ...     ...    ...    ...          ...
# 5999      First    17.57  1193.0   88.70    5.0   4.00         Tata
# 6002      First    16.09  1598.0  103.50    5.0   3.25   Volkswagen
# 6005      First    24.30  1248.0   88.50    5.0   7.43       Maruti
# 6010      First    18.50  1198.0   86.80    5.0   3.20        Honda
# 6014      First    28.40  1248.0   74.00    5.0   4.75       Maruti
#
#                            Model
# 2                         Jazz V
# 7     Innova Crysta 2.8 GX AT 8S
# 10                     Ciaz Zeta
# 15              Pajero Sport 4X4
# 20                 3 Series 320d
# ...                          ...
# 5999            Bolt Revotron XT
# 6002          Vento 1.6 Highline
# 6005           Vitara Brezza VDi
# 6010              Brio 1.2 VX MT
# 6014                   Swift VDI
#
# [823 rows x 14 columns]

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 823 entries, 2 to 6014
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         823 non-null    int64
#  1   Location           823 non-null    object
#  2   Year               823 non-null    int64
#  3   Kilometers_Driven  823 non-null    int64
#  4   Fuel_Type          823 non-null    object
#  5   Transmission       823 non-null    object
#  6   Owner_Type         823 non-null    object
#  7   Mileage            823 non-null    float64
#  8   Engine             823 non-null    float64
#  9   Power              823 non-null    float64
#  10  Seats              823 non-null    float64
#  11  Price              823 non-null    float64
#  12  Manufacturer       823 non-null    object
#  13  Model              823 non-null    object
# dtypes: float64(5), int64(3), object(6)
# memory usage: 96.4+ KB

# %%
# prompt: rename column title Mileage to Mileage(Kmpl/Kmkg), Power to Power(CC), Engine to Engine(bhp) and give column name

# Rename columns
car = car.rename(columns={'Mileage': 'Mileage(Kmpl/Kmkg)', 'Power': 'Power(CC)', 'Engine': 'Engine(bhp)'})

# Display column names
car.columns
# Out:
# Index(['Unnamed: 0', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage(Kmpl/Kmkg)', 'Engine(bhp)',
#        'Power(CC)', 'Seats', 'Price', 'Manufacturer', 'Model'],
#       dtype='object')

# %%
car.drop(['Model'],axis=1,inplace=True)
car.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
car.columns
# Out:
# Index(['Location', 'Year', 'Kilometers_Driven', 'Fuel_Type', 'Transmission',
#        'Owner_Type', 'Mileage(Kmpl/Kmkg)', 'Engine(bhp)', 'Power(CC)', 'Seats',
#        'Price', 'Manufacturer'],
#       dtype='object')

# %%
sns.pairplot(car)

# %%
# prompt: correlation metrix  for car value exclude location, fuel type, owner tyoe, transmission, Manufacturer

# Exclude specified columns for correlation matrix
cols_to_exclude = ['Location', 'Fuel_Type', 'Owner_Type', 'Transmission', 'Manufacturer']
cols_for_correlation = [col for col in car.columns if col not in cols_to_exclude]

# Calculate the correlation matrix
correlation_matrix = car[cols_for_correlation].corr()

# Display the correlation matrix
print(correlation_matrix)

# You can also visualize the correlation matrix using a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()
# Out:
#                         Year  Kilometers_Driven  Mileage(Kmpl/Kmkg)  \
# Year                1.000000          -0.520334           -0.116559
# Kilometers_Driven  -0.520334           1.000000            0.042783
# Mileage(Kmpl/Kmkg) -0.116559           0.042783            1.000000
# Engine(bhp)         0.016253           0.129182           -0.633602
# Power(CC)          -0.017271           0.006821           -0.540167
# Seats               0.074964           0.212490           -0.393457
# Price               0.227202          -0.154463           -0.433571
#
#                     Engine(bhp)  Power(CC)     Seats     Price
# Year                   0.016253  -0.017271  0.074964  0.227202
# Kilometers_Driven      0.129182   0.006821  0.212490 -0.154463
# Mileage(Kmpl/Kmkg)    -0.633602  -0.540167 -0.393457 -0.433571
# Engine(bhp)            1.000000   0.853957  0.414706  0.696675
# Power(CC)              0.853957   1.000000  0.077125  0.777187
# Seats                  0.414706   0.077125  1.000000  0.046168
# Price                  0.696675   0.777187  0.046168  1.000000

# %%
# prompt: introduce new colun of age whivh show current age of car regarding current year-Year

import datetime

current_year = datetime.datetime.now().year

def calculate_age(year):
  return current_year - year

car['Age'] = car['Year'].apply(calculate_age)

# %%
# prompt: generate histogram for Manufacturer count

plt.figure(figsize=(10, 6))
sns.countplot(x='Manufacturer', data=car)
plt.title('Manufacturer Count')
plt.xlabel('Manufacturer')
plt.ylabel('Count')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()

# %%
# prompt: encode Fuel_Type, Transmission, Owner type,Manucturer

from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
le = LabelEncoder()

# Define the columns to encode
categorical_cols = ['Fuel_Type', 'Transmission', 'Owner_Type', 'Manufacturer']

# Iterate through the columns and apply Label Encoding
for col in categorical_cols:
    car[col] = le.fit_transform(car[col])

# Display the updated DataFrame
car
# Out:
#      Location  Year  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  \
# 2     Chennai  2011              46000          2             1           0
# 7      Mumbai  2016              36000          1             0           0
# 10      Kochi  2018              25692          2             1           0
# 15      Delhi  2014             110000          1             1           0
# 20      Kochi  2014              32982          1             0           0
# ...       ...   ...                ...        ...           ...         ...
# 5999  Chennai  2016              10000          2             1           0
# 6002   Mumbai  2011              38000          2             1           0
# 6005     Pune  2016              37208          1             1           0
# 6010    Delhi  2013              33746          2             1           0
# 6014    Delhi  2014              27365          1             1           0
#
#       Mileage(Kmpl/Kmkg)  Engine(bhp)  Power(CC)  Seats  Price  Manufacturer  \
# 2                  18.20       1199.0      88.70    5.0   4.50             5
# 7                  11.36       2755.0     171.50    8.0  17.50            21
# 10                 21.56       1462.0     103.25    5.0   9.95            12
# 15                 13.50       2477.0     175.56    7.0  15.00            15
# 20                 22.69       1995.0     190.00    5.0  18.55             1
# ...                  ...          ...        ...    ...    ...           ...
# 5999               17.57       1193.0      88.70    5.0   4.00            20
# 6002               16.09       1598.0     103.50    5.0   3.25            22
# 6005               24.30       1248.0      88.50    5.0   7.43            12
# 6010               18.50       1198.0      86.80    5.0   3.20             5
# 6014               28.40       1248.0      74.00    5.0   4.75            12
#
#       Age
# 2      14
# 7       9
# 10      7
# 15     11
# 20     11
# ...   ...
# 5999    9
# 6002   14
# 6005    9
# 6010   12
# 6014   11
#
# [823 rows x 13 columns]

# %%
car
# Out:
#      Location  Year  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  \
# 2     Chennai  2011              46000          2             1           0
# 7      Mumbai  2016              36000          1             0           0
# 10      Kochi  2018              25692          2             1           0
# 15      Delhi  2014             110000          1             1           0
# 20      Kochi  2014              32982          1             0           0
# ...       ...   ...                ...        ...           ...         ...
# 5999  Chennai  2016              10000          2             1           0
# 6002   Mumbai  2011              38000          2             1           0
# 6005     Pune  2016              37208          1             1           0
# 6010    Delhi  2013              33746          2             1           0
# 6014    Delhi  2014              27365          1             1           0
#
#       Mileage(Kmpl/Kmkg)  Engine(bhp)  Power(CC)  Seats  Price  Manufacturer  \
# 2                  18.20       1199.0      88.70    5.0   4.50             5
# 7                  11.36       2755.0     171.50    8.0  17.50            21
# 10                 21.56       1462.0     103.25    5.0   9.95            12
# 15                 13.50       2477.0     175.56    7.0  15.00            15
# 20                 22.69       1995.0     190.00    5.0  18.55             1
# ...                  ...          ...        ...    ...    ...           ...
# 5999               17.57       1193.0      88.70    5.0   4.00            20
# 6002               16.09       1598.0     103.50    5.0   3.25            22
# 6005               24.30       1248.0      88.50    5.0   7.43            12
# 6010               18.50       1198.0      86.80    5.0   3.20             5
# 6014               28.40       1248.0      74.00    5.0   4.75            12
#
#       Age
# 2      14
# 7       9
# 10      7
# 15     11
# 20     11
# ...   ...
# 5999    9
# 6002   14
# 6005    9
# 6010   12
# 6014   11
#
# [823 rows x 13 columns]

# %%
# prompt: for the linear regression model split the data into train and test with test size 0.3
# for x drop location, year, Price

from sklearn.model_selection import train_test_split

# Define features (X) and target (y)
X = car.drop(['Location', 'Year', 'Price'], axis=1)
y = car['Price']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# prompt: generate linear regrestion model train and test

from sklearn.linear_model import LinearRegression

# Initialize and train the linear regression model
lr = LinearRegression()
lr.fit(X_train,y_train)

# Make predictions on the test set
y_pred = lr.predict(X_test)

# Evaluate the model (example: R-squared)
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print(f"R-squared: {r2}")
# Out:
# R-squared: 0.6962351830676967

# %%
# prompt: detail about lr and statestic signicance table

import statsmodels.api as sm

# Add a constant to the independent variables
X_train_sm = sm.add_constant(X_train)

# Fit the OLS model
lr_sm = sm.OLS(y_train, X_train_sm).fit()

# Print the summary of the model
print(lr_sm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.684
# Model:                            OLS   Adj. R-squared:                  0.679
# Method:                 Least Squares   F-statistic:                     122.4
# Date:                Fri, 02 May 2025   Prob (F-statistic):          2.48e-134
# Time:                        07:18:55   Log-Likelihood:                -2043.5
# No. Observations:                 576   AIC:                             4109.
# Df Residuals:                     565   BIC:                             4157.
# Df Model:                          10
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 25.3746      6.553      3.872      0.000      12.503      38.247
# Kilometers_Driven  -5.403e-05   1.61e-05     -3.354      0.001   -8.57e-05   -2.24e-05
# Fuel_Type             -4.0547      0.973     -4.168      0.000      -5.966      -2.144
# Transmission          -3.5396      0.934     -3.789      0.000      -5.374      -1.705
# Owner_Type             0.1896      1.393      0.136      0.892      -2.547       2.926
# Mileage(Kmpl/Kmkg)    -0.1341      0.129     -1.039      0.299      -0.388       0.119
# Engine(bhp)            0.0066      0.002      3.675      0.000       0.003       0.010
# Power(CC)              0.1121      0.016      7.107      0.000       0.081       0.143
# Seats                 -2.3036      0.624     -3.690      0.000      -3.530      -1.077
# Manufacturer          -0.0510      0.059     -0.869      0.385      -0.166       0.064
# Age                   -1.1154      0.188     -5.930      0.000      -1.485      -0.746
# ==============================================================================
# Omnibus:                      619.981   Durbin-Watson:                   2.063
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            94111.038
# Skew:                           4.536   Prob(JB):                         0.00
# Kurtosis:                      64.960   Cond. No.                     9.26e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.26e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# prompt: dropwhich varible p value higher than 0.05 and retrain model

# Get p-values from the statsmodels summary
p_values = lr_sm.pvalues

# Identify variables with p-values > 0.05
variables_to_drop = p_values[p_values > 0.05].index.tolist()

# Remove the constant from the list of variables to drop
if 'const' in variables_to_drop:
    variables_to_drop.remove('const')

# Drop the insignificant variables from the feature set
X_train_new = X_train.drop(variables_to_drop, axis=1)
X_test_new = X_test.drop(variables_to_drop, axis=1)

# Retrain the model with the reduced feature set
lr_new = LinearRegression()
lr_new.fit(X_train_new, y_train)

# Make predictions on the test set
y_pred_new = lr_new.predict(X_test_new)

# Evaluate the new model
r2_new = r2_score(y_test, y_pred_new)
print(f"R-squared after removing insignificant variables: {r2_new}")

# Add a constant to the new independent variables and refit statsmodels
X_train_sm_new = sm.add_constant(X_train_new)
lr_sm_new = sm.OLS(y_train, X_train_sm_new).fit()
print(lr_sm_new.summary())
# Out:
# R-squared after removing insignificant variables: 0.6929737300204813
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.683
# Model:                            OLS   Adj. R-squared:                  0.679
# Method:                 Least Squares   F-statistic:                     175.0
# Date:                Fri, 02 May 2025   Prob (F-statistic):          2.62e-137
# Time:                        07:20:05   Log-Likelihood:                -2044.3
# No. Observations:                 576   AIC:                             4105.
# Df Residuals:                     568   BIC:                             4139.
# Df Model:                           7
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                19.4059      3.634      5.340      0.000      12.268      26.543
# Kilometers_Driven -5.468e-05    1.6e-05     -3.419      0.001   -8.61e-05   -2.33e-05
# Fuel_Type            -3.5323      0.791     -4.466      0.000      -5.086      -1.979
# Transmission         -3.5933      0.930     -3.862      0.000      -5.421      -1.766
# Engine(bhp)           0.0070      0.002      4.256      0.000       0.004       0.010
# Power(CC)             0.1164      0.015      7.685      0.000       0.087       0.146
# Seats                -2.1173      0.595     -3.557      0.000      -3.287      -0.948
# Age                  -1.1196      0.184     -6.074      0.000      -1.482      -0.758
# ==============================================================================
# Omnibus:                      616.403   Durbin-Watson:                   2.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            94093.323
# Skew:                           4.485   Prob(JB):                         0.00
# Kurtosis:                      64.968   Cond. No.                     5.17e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.17e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(lr,X_test,y_test,cv=5)
# Out:
# array([0.65014492, 0.64778791, 0.74215159, 0.63743669, 0.81097732])

# %%
import pickle
filename='car_price_prediction.sav'
pickle.dump(lr,open(filename,'wb'))
